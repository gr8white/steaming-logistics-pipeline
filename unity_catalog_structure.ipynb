# %% [markdown]
# ### Create the unity Catalog Structure
# This creates the `rapidroute` catalog and all three medallion schemas.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS rapidroute;

USE CATALOG rapidroute;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %% [markdown]
# ### Create the Volume and Seed Initial Data
# The Volume that will receive incoming event files.

# %%
# %sql
CREATE VOLUME IF NOT EXISTS rapidroute.bronze.raw_events;

# %%
from src.utils.generate_events import generate_batch

generate_batch(n_shipments=200, batch_id=1)
generate_batch(n_shipments=150, batch_id=2)
generate_batch(n_shipments=175, batch_id=3)

# %% [markdown]
# Navigate to **Catalog → rapidroute → bronze → Volumes → raw_events** in the UI and confirm the three JSON files are visible before moving on.

# %%
import os
files = os.listdir("/Volumes/rapidroute/bronze/raw_events")
print(f"{len(files)} files found")
for f in files:
    print(f)
